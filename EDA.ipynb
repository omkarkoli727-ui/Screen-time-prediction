# %% [markdown]
# 1.Problem statement - finding out the Stress level by Screen Time and Sleep
# Identify the target - Stress level
# Identify type - Regression

# %% [markdown]
# 2.Data
# Gathering required data.
# Ex(Kaggle,github,huggingfaces,some official websites)
# link : https://www.kaggle.com/datasets/amar5693/screen-time-sleep-and-stress-analysis-dataset

# %% [markdown]
# 3.Data Loading

# %%
import pandas as pd

# %%
data=pd.read_csv(r"Smartphone_Usage_Productivity_Dataset_50000.csv")
#so first I need pandas library (for Data manipulation) then the above code will work

# %% [markdown]
# 4.EDA-Exploratory data analysis

# %%
data.head()   # top 5 rows
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# ...

# %%
data.tail(3)  # bottom 3 rows
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 49997  U49998   27  Female      Freelancer         iOS                1.4
# 49998  U49999   41  Female  Business Owner         iOS                8.9
# 49999  U50000   46   Other      Freelancer     Android                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 49997                 2.5                        4          6.7             9
# 49998                 3.0                        6          5.5             2
# 49999                 2.8                        3          5.4             1
#
#        App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# 49997               39                     4                        5.1
# 49998               51                     0                        9.2
# 49999               54                     5                        6.9

# %%
data.info()   # data types and non null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50000 non-null  object
#  1   Age                        50000 non-null  int64
#  2   Gender                     50000 non-null  object
#  3   Occupation                 50000 non-null  object
#  4   Device_Type                50000 non-null  object
#  5   Daily_Phone_Hours          50000 non-null  float64
#  6   Social_Media_Hours         50000 non-null  float64
#  7   Work_Productivity_Score    50000 non-null  int64
#  8   Sleep_Hours                50000 non-null  float64
#  9   Stress_Level               50000 non-null  int64
#  10  App_Usage_Count            50000 non-null  int64
#  11  Caffeine_Intake_Cups       50000 non-null  int64
#  12  Weekend_Screen_Time_Hours  50000 non-null  float64
# ...

# %%
data.describe()  # summary statistics of numerical columns
# Out:
#                 Age  Daily_Phone_Hours  Social_Media_Hours  \
# count  50000.000000       50000.000000        50000.000000
# mean      39.034960           6.509116            4.267250
# std       12.414877           3.170903            2.164743
# min       18.000000           1.000000            0.500000
# 25%       28.000000           3.800000            2.400000
# 50%       39.000000           6.500000            4.300000
# 75%       50.000000           9.200000            6.100000
# max       60.000000          12.000000            8.000000
#
#        Work_Productivity_Score   Sleep_Hours  Stress_Level  App_Usage_Count  \
# count             50000.000000  50000.000000  50000.000000      50000.00000
# mean                  5.503760      6.497744      5.504500         32.43898
# std                   2.874806      1.449551      2.871095         16.12151
# min                   1.000000      4.000000      1.000000          5.00000
# ...

# %%
data.describe(include='all') # summary statistics of all columns  , you can add include='object' to get summary of only categorical columns
# Out:
#        User_ID           Age Gender    Occupation Device_Type  \
# count    50000  50000.000000  50000         50000       50000
# unique   50000           NaN      3             4           2
# top     U49984           NaN   Male  Professional     Android
# freq         1           NaN  16708         12629       25080
# mean       NaN     39.034960    NaN           NaN         NaN
# std        NaN     12.414877    NaN           NaN         NaN
# min        NaN     18.000000    NaN           NaN         NaN
# 25%        NaN     28.000000    NaN           NaN         NaN
# 50%        NaN     39.000000    NaN           NaN         NaN
# 75%        NaN     50.000000    NaN           NaN         NaN
# max        NaN     60.000000    NaN           NaN         NaN
#
#         Daily_Phone_Hours  Social_Media_Hours  Work_Productivity_Score  \
# count        50000.000000        50000.000000             50000.000000
# unique                NaN                 NaN                      NaN
# ...

# %%
data.shape   # number of rows and columns
# Out:
# (50000, 13)

# %%
data.isnull().sum()  # count of missing values in each column
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# dtype: int64

# %% [markdown]
# NO null values present in any Columns

# %%
data.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Occupation', 'Device_Type',
#        'Daily_Phone_Hours', 'Social_Media_Hours', 'Work_Productivity_Score',
#        'Sleep_Hours', 'Stress_Level', 'App_Usage_Count',
#        'Caffeine_Intake_Cups', 'Weekend_Screen_Time_Hours'],
#       dtype='object')

# %%
data["Stress_Level"].describe()  # access a single column
# Out:
# count    50000.000000
# mean         5.504500
# std          2.871095
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          8.000000
# max         10.000000
# Name: Stress_Level, dtype: float64

# %% [markdown]
# Stress Lavel Range is between 1 to 10
# average is : 5.5

# %%
data[["Sleep_Hours",'Weekend_Screen_Time_Hours']].describe()  # access multiple columns
# Out:
#         Sleep_Hours  Weekend_Screen_Time_Hours
# count  50000.000000               50000.000000
# mean       6.497744                   8.006844
# std        1.449551                   3.461300
# min        4.000000                   2.000000
# 25%        5.200000                   5.000000
# 50%        6.500000                   8.000000
# 75%        7.800000                  11.000000
# max        9.000000                  14.000000

# %% [markdown]
# Sleep_Hours Range is between 4 to 9
# average is : 6
#
# Weekend Screen Time Hours Range is between 2 to 14 Hours
# average is : 8 Hours

# %%
data["Stress_Level"].unique()# unique values in a column
# Out:
# array([ 4,  1,  3,  7,  2,  9, 10,  8,  5,  6])

# %%
data["Stress_Level"].value_counts()  # count of unique values in a column
# Out:
# Stress_Level
# 5     5096
# 6     5076
# 2     5058
# 10    5031
# 3     5009
# 9     4993
# 8     4993
# 1     4940
# 7     4933
# 4     4871
# Name: count, dtype: int64

# %% [markdown]
# Visualization (matplotlib,seaborn)

# %%
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50000 non-null  object
#  1   Age                        50000 non-null  int64
#  2   Gender                     50000 non-null  object
#  3   Occupation                 50000 non-null  object
#  4   Device_Type                50000 non-null  object
#  5   Daily_Phone_Hours          50000 non-null  float64
#  6   Social_Media_Hours         50000 non-null  float64
#  7   Work_Productivity_Score    50000 non-null  int64
#  8   Sleep_Hours                50000 non-null  float64
#  9   Stress_Level               50000 non-null  int64
#  10  App_Usage_Count            50000 non-null  int64
#  11  Caffeine_Intake_Cups       50000 non-null  int64
#  12  Weekend_Screen_Time_Hours  50000 non-null  float64
# ...

# %%
first_four=data[["Age","Daily_Phone_Hours","Social_Media_Hours","Work_Productivity_Score"]]
second_four=data[["Sleep_Hours","Stress_Level","App_Usage_Count","Weekend_Screen_Time_Hours"]]

# %%
plt.figure(figsize=(12,8))
sns.boxplot(first_four)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(second_four)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data["Caffeine_Intake_Cups"])
plt.show()

# %% [markdown]
# There is no outliers existed

# %%
plt.figure(figsize=(10,5))
plt.pie(data["Gender"].value_counts(),labels=data["Gender"].unique(),autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.pie(data["Device_Type"].value_counts(),labels=data["Device_Type"].unique(),autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data[["Daily_Phone_Hours","Sleep_Hours"]])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(data["Age"])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data["App_Usage_Count"])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data["Weekend_Screen_Time_Hours"])
plt.show()
